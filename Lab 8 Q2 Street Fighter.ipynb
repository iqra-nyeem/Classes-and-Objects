# %%
class student:
#     __totalstudent = 100
    def __init__(self):
        self.__privatemethod()
        
    def study(self):
        print("LLLLL")
    def __privatemethod(self):
        print("OOOO")
        
st = student()
st.study()
# Out:
# OOOO
# LLLLL

# %%
class SF:
    pass
class Lee(SF):
    __BloodType = "O"
a = Lee()
print(a._Lee__BloodType)
# Out:
# O

# %%
class Street_Fighter:
    def __init__(self,Height,Weight,EyeColor,HairColor):
        self.Height = Height
        self.Weight = Weight
        self.EyeColor = EyeColor
        self.HairColor = HairColor

    def SF(self):

        Number_of_Street_Fighter = int(input("Number of Street_Fighter for today's Match: "))
        StreetFighter = {}
        for x in range(Number_of_Street_Fighter):
            StreetFighter[x] = (str(input("Name: ")))
            if StreetFighter[x] == "Lee":
                print('Lee')
                Obj_Street_Fighter = Street_Fighter('167 cm','96 KG','Blue','Brown')
                Obj_Street_Fighter.SF
                Obj_Lee = Lee(167,96,'Blue','Brown')
                print("Lee has height of {}.".format(Obj_Lee.Height))
                print("Lee has Weight of {}.".format(Obj_Lee.Weight))
                print("Lee has {} Hairs.".format(Obj_Lee.HairColor))
                print("Lee has {} eyes.".format(Obj_Lee.EyeColor))
                Obj_Lee.Block()
                Obj_Lee.Speed()
                Obj_Lee.Country()
                Obj_Lee.defense_resistance()
                Obj_Lee.Attack()
                Obj_Lee.Special_Power()
                print("Lee has Blood Group {}".format(Obj_Lee._Lee__BloodType))
                
            elif StreetFighter[x] == "Ryu":
                Obj_Street_Fighter = Street_Fighter(167,96,'Blue','Brown')
                Obj_Street_Fighter.SF
                Obj_Ryu = Ryu("175 cm","85 KG",'Brown',"Red")
                print("Ryu has height of {}.".format(Obj_Ryu.Height))
                print("Ryu has Weight of {}.".format(Obj_Ryu.Weight))
                print("Ryu has {} Hairs.".format(Obj_Ryu.HairColor))
                print("Ryu has {} eyes.".format(Obj_Ryu.EyeColor))
                Obj_Ryu.Block()
                Obj_Ryu.Speed()
                Obj_Ryu.Country()
                Obj_Ryu.defense_resistance()
                Obj_Ryu.Attack()
                Obj_Ryu.Special_Power()
                
            elif StreetFighter[x] == "M_Bison":
                Obj_Street_Fighter = Street_Fighter(167,96,'Blue','Brown')
                Obj_Street_Fighter.SF
                Obj_M_Bison = M_Bison("180 cm","112 KG",'Ghastly White',"Black")
                print("M_Bison has height of {}.".format(Obj_M_Bison.Height))
                print("M_Bison has Weight of {}.".format(Obj_M_Bison.Weight))
                print("M_Bison has {} Hairs.".format(Obj_M_Bison.HairColor))
                print("M_Bison has {} eyes.".format(Obj_M_Bison.EyeColor))
                Obj_M_Bison.Block()
                Obj_M_Bison.Speed()
                Obj_M_Bison.Country()
                Obj_M_Bison.defense_resistance()
                Obj_M_Bison.Attack()
                Obj_M_Bison.Special_Power()


            else:
                return ("Plz Enter Correct Spelling")
                Obj_Street_Fighter.SF()
 
class Lee(Street_Fighter):
    __BloodType = "O"
    def Speed(self):
        print("Lee's Speed is 3.5")

    def Special_Power(self):
        print('Lee has Special_Power of dashing punch')

    def Country(self):
        print("Lee is a Chinese martial artist.")
        
    def defense_resistance(self):
        print("Lee has a Power of Defense")
        
    def Attack(self):
        print("Bajiquan and Drunken Fist")
        
    def Block(self):
        print("Lee has a Block Power") 
        
class Ryu(Street_Fighter):
    def Speed(self):
        print("Ryu has Speed Power of 2.9")

    def Special_Power(self):
        print('Lee has Special_Power of Martial Art')

    def Country(self):
        print("Ryu belongs to Japan.")
        
    def defense_resistance(self):
        print("Ryu has a Power of Defense")
        
    def Attack(self):
        print("Versatile move set.")
        
    def Block(self):
        print("Ryu has ability to dash out of his Fireball to bait Jumps or set up a throw attempt") 

class M_Bison(Street_Fighter):
    def Speed(self):
        print("M_Bison has Speed Power of 2.9")

    def Special_Power(self):
        print('Psycho Power')

    def Country(self):
        print("M_Bison belongs to Thailand.")
        
    def defense_resistance(self):
        print("M_Bison has a Power of Defense")
        
    def Attack(self):
        print("Hypnosis")
        
    def Block(self):
        print("M_Bison has ability to dash out from set up a throw attempt")
Obj_Street_Fighter = Street_Fighter(167,96,'Blue','Brown')
Obj_Street_Fighter.SF()
# Out:
# Number of Street_Fighter for today's Match: 2
# Name: Ryu
# Ryu has height of 175 cm.
# Ryu has Weight of 85 KG.
# Ryu has Red Hairs.
# Ryu has Brown eyes.
# Ryu has ability to dash out of his Fireball to bait Jumps or set up a throw attempt
# Ryu has Speed Power of 2.9
# Ryu belongs to Japan.
# Ryu has a Power of Defense
# Versatile move set.
# Lee has Special_Power of Martial Art
# Name: Lee
# Lee
# Lee has height of 167.
# Lee has Weight of 96.
# Lee has Brown Hairs.
# Lee has Blue eyes.
# Lee has a Block Power
# Lee's Speed is 3.5
# Lee is a Chinese martial artist.
# Lee has a Power of Defense
# Bajiquan and Drunken Fist
# Lee has Special_Power of dashing punch
# Lee has Blood Group O
